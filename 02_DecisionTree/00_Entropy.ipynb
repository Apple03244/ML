# %%
from pandas import read_csv
from scipy import stats

# %%
data=read_csv("../데이터/고객대출등급예측.csv")

# %%
pks=data.대출등급.value_counts(normalize=True)

# %%
pks
# Out:
# 대출등급
# B    0.299261
# C    0.286861
# A    0.174175
# D    0.138679
# E    0.076370
# F    0.020292
# G    0.004362
# Name: proportion, dtype: float64

# %%
stats.entropy(pks)
# Out:
# np.float64(1.596868934523157)

# %%
data.주택소유상태.value_counts()
# Out:
# 주택소유상태
# MORTGAGE    47934
# RENT        37705
# OWN         10654
# ANY             1
# Name: count, dtype: int64
